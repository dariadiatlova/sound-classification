# %% [markdown]
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://drive.google.com/file/d/1OrflCw_rAxU7ssAWnEHqSWBBjBJnK08U/view?usp=sharing)

# %%
# !git clone https://github.com/dariadiatlova/urban-sound-classification

# %%
cd urban-sound-classification
# Out:
# /content/urban-sound-classification

# %%
# !pip install -r requirements.txt

# %%
# !pip install torchtext

# %%
from src.preprocessing.audio_util_load import load_wav_file
from IPython import display

# %% [markdown]
# ### Test launch: car_horn

# %%
test_sample_path = "src/evaluation/data/2937-1-0-0.wav"
signal, sr = load_wav_file(test_sample_path)

# %%
display.Audio(data=signal, rate=sr)
# Out:
#                 <audio controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
# !python3 -m src.evaluation.evaluate -p "src/evaluation/data/2937-1-0-0.wav" -w "src/artifacts/epoch23.ckpt"
# Out:
# Predicted class for the audio: gun_shot

# %% [markdown]
# ### Test launch: engine_idling

# %%
test_sample_path = "src/evaluation/data/17578-5-0-5.wav"
signal, sr = load_wav_file(test_sample_path)

# %%
display.Audio(data=signal, rate=sr)
# Out:
#                 <audio controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
# !python3 -m src.evaluation.evaluate -p "src/evaluation/data/17578-5-0-5.wav" -w "src/artifacts/epoch23.ckpt"
# Out:
# Predicted class for the audio: engine_idling

# %% [markdown]
# ### Test launch: street_music

# %%
test_sample_path = "src/evaluation/data/55728-9-0-30.wav"
signal, sr = load_wav_file(test_sample_path)

# %%
display.Audio(data=signal, rate=sr)
# Out:
#                 <audio controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
# !python3 -m src.evaluation.evaluate -p "src/evaluation/data/55728-9-0-30.wav" -w "src/artifacts/epoch23.ckpt"
# Out:
# Predicted class for the audio: street_music

# %% [markdown]
# ### Test launch: dog_bark

# %%
test_sample_path = "src/evaluation/data/103076-3-0-0.wav"
signal, sr = load_wav_file(test_sample_path)

# %%
display.Audio(data=signal, rate=sr)
# Out:
#                 <audio controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
# !python3 -m src.evaluation.evaluate -p "src/evaluation/data/103076-3-0-0.wav" -w "src/artifacts/epoch23.ckpt"
# Out:
# Predicted class for the audio: dog_bark
